# %% [markdown]
# <a href="https://colab.research.google.com/github/SandroOlaf/Todo-List/blob/main/Todo_Lis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lista principal para armazenar as tarefas.
# Cada elemento da lista será um dicionário.
lista_de_tarefas = []

# Tupla para opções fixas de status
STATUS_CONCLUIDA = "Concluída"
STATUS_PENDENTE = "Pendente"
OPCOES_STATUS = (STATUS_PENDENTE, STATUS_CONCLUIDA)


def adicionar_tarefa():
    """Adiciona um novo dicionário de tarefa à lista principal."""
    # 1. Solicitar o nome da tarefa ao usuário.
    nome = input("Digite o nome da tarefa: ")
    # 2. Verificar se o nome não está vazio.
    if not nome:
      print("Nenhuma tarefa localizada")
      return
    # 3. Solicitar a prioridade (Alta, Média, Baixa).
    prioridade = input("Digite a prioridade(Alta, Média, Baixa): ")
    # 4. Criar um dicionário com nome, prioridade e status inicial (PENDENTE).
    nova_tarefa = {
        "nome": nome,
        "prioridade": prioridade,
        "status": STATUS_PENDENTE
    }
    # 5. Adicionar o dicionário à lista_de_tarefas.
    lista_de_tarefas.append(nova_tarefa)
    # 6. Imprimir mensagem de sucesso.
    print(f"Você adicionou a tarefa com sucesso!")



def mostrar_tarefas():
    """Exibe todas as tarefas com seus detalhes e status."""
    # 1. Verificar se a lista está vazia. Se sim, imprimir uma mensagem e retornar.
    if not lista_de_tarefas:
      print("Lista Vazia")
    # 2. Imprimir um cabeçalho.
    print("\n--- TAREFAS ----")
    # 3. Iterar sobre a lista usando enumerate para obter o índice (i) e a tarefa.
    for i, tarefa in enumerate(lista_de_tarefas):
        # 4. Calcular o índice visual (i + 1).
        indice_visual = i + 1
        # 5. NOVO PASSO::
        #Use o método .get() para acessar os valores do dicionário (nome, status, prioridade)
        nome = tarefa.get("nome", "Não localizado")
        prioridade = tarefa.get("prioridade", "N/A")
        status = tarefa.get("status", "STATUS_PENDENTE")
        #    e forneça um valor padrão (ex: "Nome Indefinido", STATUS_PENDENTE, "N/A") caso a chave não exista.
        # 6. Usar um condicional ternário para definir o marcador ("[X]" ou "[ ]").
        marcador = "[X]" if lista_de_tarefas == STATUS_CONCLUIDA else "[ ]"
        # 7. Imprimir o índice visual, marcador, nome e prioridade de cada tarefa.
        print(f"{indice_visual} {marcador} {nome} (Prioridade : {prioridade})")


def concluir_tarefa():
    """Marca uma tarefa como 'Concluída'."""
    # 1. Chamar mostrar_tarefas().
    mostrar_tarefas()
    # 2. Se a lista estiver vazia, retornar.
    if not lista_de_tarefas:
      print('Lista Vazia!')
      return
    # 3. Usar try/except para tratar erros de entrada (ValueError).
    try:
        # 4. Solicitar o NÚMERO da tarefa para concluir.
        indice_input = int(input('Digite o número da tarefa: '))
        # 5. Converter o número de entrada para o ÍNDICE real (número - 1).
        indice_real = indice_input - 1
        # 6. Usar um condicional para checar se o índice é válido (0 <= indice < len(lista)).
        if 0 <= indice_input < len(lista_de_tarefas) !
        # 7. Se válido, acessar o dicionário na lista e alterar a chave "status" para STATUS_CONCLUIDA.
        # 8. Imprimir mensagem de sucesso ou erro (se o número for inválido).
    except ValueError:
          print("Voce digitou um valor incorreto!")




def remover_tarefa():
    """Remove uma tarefa da lista principal pelo seu número."""
    # 1. Chamar mostrar_tarefas().

    # 2. Se a lista estiver vazia, retornar.
    # 3. Usar try/except para tratar erros de entrada (ValueError).
    # 4. Solicitar o NÚMERO da tarefa para remover.
    # 5. Converter o número de entrada para o ÍNDICE real.
    # 6. Usar um condicional para checar se o índice é válido.
    # 7. Se válido, use o comando 'del' para remover o item: del lista_de_tarefas[indice_real].
    # 8. Imprimir mensagem de sucesso ou erro (se o número for inválido).
    pass


# 4. Loop Principal do Programa
# 🙋‍♂️ SEU CÓDIGO COMEÇA AQUI!

# 1. Crie um loop infinito (while True).
# 2. Imprima o MENU com as 5 opções.
# 3. Peça ao usuário que selecione uma opção.
# 4. Use estruturas if/elif para chamar a função correta ('1' chama adicionar_tarefa(), '2' chama mostrar_tarefas(), etc.).
# 5. Use o 'break' na opção '5' (Sair) para terminar o loop.
# 6. Use o 'else' para tratar opções inválidas.

# ... SEU CÓDIGO TERMINA AQUI!
